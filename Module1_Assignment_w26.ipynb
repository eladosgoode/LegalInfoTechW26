# %% [markdown]
# <a href="https://colab.research.google.com/github/eladosgoode/LegalInfoTechW26/blob/main/Module1_Assignment_w26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 1: Assignment

# %% [markdown]
# ## Instructions
#
# You should begin by viewing Lesson 1 on eClass (and note that the lesson includes a link to the notebook used in the videos).
#
# Next, everyone should attempt to complete the beginner and intermediate sections of this assignment. If you are interested you can continue to advanced. Whether you choose to go beyond the beginner and intermediate sections will not affect your participation grade, but some of the skills you learn (or relearn) may be helpful for your final project for the course.
#
#
# In addition, everyone should complete the final reflection section.
#
#
# Combined, the lesson and assignment should not take you more than three hours -- so if you get to that point, just move on to the reflective section (and add a text/markdown cell to the notebook indicating where you stopped and saying that you hit the 3 hour limit).
#
#
# When you have finished, upload a copy of the .ipynb file to eClass assignment page.
#
# NOTE: If you are using Colab and you downloaded this file by clicking on "Open in Colab" on Github, make sure to save a copy of this file on your Google Drive by selecting File, Save.

# %% [markdown]
# ## Beginner

# %% [markdown]
# ### Beginner Question 1:
#
# Using the code cell below, print Hello World.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Beginner Question 2:
#
# In 1875, the Supreme Court of Canada was established under the Supreme Court Act. In 1982, Bertha Wilson became the first woman appointed to the Supreme Court of Canada. Assume for the sake of simplicity that both events happened on the same day of the year.
# In the code cell below:
#
# Create a variable storing the year the Supreme Court of Canada was established.
# Create a variable storing the year the first woman was appointed to the Supreme Court.
# Create a variable that calculates the number of years between these two events.
# Create a variable that calculates the number of months between these two events.
# Print: "It took # months from the establishment of the Supreme Court of Canada for a woman to be appointed to the bench."

# %%
supremeCourtEstablished = 1875
firstWomanSupremeCourt = 1982

monthsBetweenEstablishAndWoman = (1982 - 1875) * 12

print("It took " + str(monthsBetweenEstablishAndWoman) + " months from the establishment of the Supreme Court of Canada for a woman to be appointed to the bench.")
# Out:
# It took 1284 months from the establishment of the Supreme Court of Canada for a woman to be appointed to the bench.

# %% [markdown]
# ### Beginner Question 3:
#
# The code cell below includes a list of current Supreme Court of Canada judges. Using this list, produce the exact output below using the print function. Note that the Chief Justice has a different honorific. Desired Output:
#
# The Right Honourable Chief Justice Richard Wagner
#
# The Honourable Justice Andromache Karakatsanis
#
# The Honourable Justice Suzanne Côté
#
# The Honourable Justice Malcolm Rowe
#
# The Honourable Justice Sheilah Martin
#
# The Honourable Justice Nicholas Kasirer
#
# The Honourable Justice Mahmud Jamal
#
# The Honourable Justice Michelle O'Bonsawin
#
# The Honourable Justice Mary Moreau

# %%
list_of_judges = [
    "Richard Wagner",
    "Andromache Karakatsanis",
    "Suzanne Côté",
    "Malcolm Rowe",
    "Sheilah Martin",
    "Nicholas Kasirer",
    "Mahmud Jamal",
    "Michelle O'Bonsawin",
    "Mary Moreau"
]

# %%
list_of_judges = [
    "Richard Wagner",
    "Andromache Karakatsanis",
    "Suzanne Côté",
    "Malcolm Rowe",
    "Sheilah Martin",
    "Nicholas Kasirer",
    "Mahmud Jamal",
    "Michelle O'Bonsawin",
    "Mary Moreau"
]

for name in list_of_judges:
  if name == "Richard Wagner":
    print ("The Right Honourable Chief Justice Richard Wagner")
  else:
    print ("The Honourable Justice " + name)
# Out:
# The Right Honourable Chief Justice Richard Wagner
# The Honourable Justice Andromache Karakatsanis
# The Honourable Justice Suzanne Côté
# The Honourable Justice Malcolm Rowe
# The Honourable Justice Sheilah Martin
# The Honourable Justice Nicholas Kasirer
# The Honourable Justice Mahmud Jamal
# The Honourable Justice Michelle O'Bonsawin
# The Honourable Justice Mary Moreau

# %% [markdown]
# ### Beginner Question 4:
#
# Run the code cell below. It should not work properly. Fix the code and run it.

# %%
# Check if this is a federal statute

citation = "RSC 1985, c C-46"

if "RSC" in citation:
    print("This is a federal statute")
else:
    print("This is not a federal statute")
# Out:
# This is a federal statute

# %% [markdown]
# ## Intermediate

# %% [markdown]
# ### Intermediate Question 1:
#
# Using the same list as for beginner question 3 (and without making any changes to the list itself), produce the following output:
#
# Wagner C.J.
#
# Karakatsanis J.
#
# Côté J.
#
# Rowe J.
#
# Martin J.
#
# Kasirer J.
#
# Jamal J.
#
# O'Bonsawin J.
#
# Moreau J.

# %%
list_of_judges = [
    "Richard Wagner",
    "Andromache Karakatsanis",
    "Suzanne Côté",
    "Malcolm Rowe",
    "Sheilah Martin",
    "Nicholas Kasirer",
    "Mahmud Jamal",
    "Michelle O'Bonsawin",
    "Mary Moreau"
]

for name in list_of_judges:
  if name == "Richard Wagner":
    print (name.split()[1] + " C.J.")
  else:
    print(name.split()[1] + " J.")
# Out:
# Wagner C.J.
# Karakatsanis J.
# Côté J.
# Rowe J.
# Martin J.
# Kasirer J.
# Jamal J.
# O'Bonsawin J.
# Moreau J.

# %% [markdown]
# ### Intermediate Question 2:
#
# The code cell below includes a dictionary with the highest neutral citation for Federal Court cases for several years. For example in 2020, neutral citations go from "2020 FC 1" to "2020 FC 6805". In other words, the first federal court case in 2020 is "2020 FC 1", the second is "2020 FC 2", and so on until "2020 FC 6805".
#
# Create a variable with a dictionary that uses each year from 2013 to 2022 as keys, and the values associated with those keys should be a list of all the neutral citations for that year. You can imagine that this dictionary would be used to scrape each decision from the federal court website.

# %%
highest_neutral_citation =  {
    2013: 8428,
    2014: 8508,
    2015: 5901,
    2016: 5412,
    2017: 5641,
    2018: 6616,
    2019: 7910,
    2020: 6805,
    2021: 9832,
    2022: 13672
}

dictionaryOfYears = {}

for key in highest_neutral_citation:
  listForYear = []
  for i in range (1, highest_neutral_citation[key] + 1):
    listForYear.append(str(key) + " FC " + str(i))
  dictionaryOfYears[key] = listForYear

# %% [markdown]
# ### Intermediate Question 3:
#
# Run the code cell below. It should not work as expected. Fix the code and run it.

# %%
# Say hello to all 9 SCC judges from the list of judges
# in beginner question 3

list_of_judges = [
    "Richard Wagner",
    "Andromache Karakatsanis",
    "Suzanne Côté",
    "Malcolm Rowe",
    "Sheilah Martin",
    "Nicholas Kasirer",
    "Mahmud Jamal",
    "Michelle O'Bonsawin",
    "Mary Moreau"
]

def say_hi(name):
  print("Hello " + name)

def say_hi_to_judges(judges):
  for judge in judges:
    say_hi(judge)

say_hi_to_judges(list_of_judges)
# Out:
# Hello Richard Wagner
# Hello Andromache Karakatsanis
# Hello Suzanne Côté
# Hello Malcolm Rowe
# Hello Sheilah Martin
# Hello Nicholas Kasirer
# Hello Mahmud Jamal
# Hello Michelle O'Bonsawin
# Hello Mary Moreau

# %% [markdown]
# ## Advanced

# %% [markdown]
# ### Advanced Question 1:
#
# Search for coding exercises that you have completed in the past, perhaps for a course. If you don't have any on hand, you can find some problem sets in Harvard's [CS50](https://cs50.harvard.edu/python/2022). Use generative AI prompts (in Colab's generate with AI function, Github's CoPilot, or OpenAI's ChatGPT) to create code that solves the problem. Does the code provided work? Is it similar to how you would have solved the problem? Paste one example below.

# %% [markdown]
# ## Reflection
#
# Add a markdown (text) cell below and describe something that you learned in completing this module that you found challenging or interesting and explain why (approx 200-400 words). Try to use formatting (headings, etc).
